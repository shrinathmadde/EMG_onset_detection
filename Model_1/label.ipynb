# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import os
from pathlib import Path
import json
from tqdm import tqdm

def get_json_labels(json_file_path):
    """Extract pre-existing labels from JSON file"""
    try:
        with open(json_file_path, 'r') as f:
            data = json.load(f)
        
        # Check if file contains ZM data with onset/offset info
        if 'ZM' in data and isinstance(data['ZM'], dict):
            zm_data = data['ZM']
            
            # Extract onset and offset
            if 'onset' in zm_data and 'offset' in zm_data:
                onsets = zm_data['onset']
                offsets = zm_data['offset']
                
                # Convert to lists if not already
                if not isinstance(onsets, list):
                    onsets = [onsets]
                if not isinstance(offsets, list):
                    offsets = [offsets]
                
                # Create mapping of all valid onset/offset pairs for each epoch
                epoch_labels = {}
                
                for i in range(len(onsets)):
                    if i < len(offsets) and onsets[i] is not None and offsets[i] is not None:
                        epoch_idx = i
                        # Store as a tuple (onset, offset)
                        epoch_labels[epoch_idx] = (onsets[i], offsets[i])
                
                return epoch_labels
        
        return {}
    except Exception as e:
        print(f"Error reading JSON labels: {str(e)}")
        return {}

def load_emg_data(data_dir):
    """Load EMG data from .fdt files with channel information from JSON"""
    # Find .fdt files
    fdt_files = list(Path(data_dir).glob('*.fdt'))
    
    if not fdt_files:
        print("No .fdt files found.")
        return [], [], []
    
    all_epochs = []
    epoch_names = []
    pre_labels = []
    
    for fdt_file in fdt_files:
        print(f"Processing: {fdt_file}")
        
        # Find corresponding .json file
        json_file = fdt_file.with_suffix('.json')
        
        if json_file.exists():
            # Get pre-existing labels if available
            epoch_labels = get_json_labels(json_file)
        else:
            print(f"No metadata file found for {fdt_file}")
            epoch_labels = {}
        
        # Load binary data
        try:
            raw_data = np.fromfile(str(fdt_file), dtype=np.float32)
            print(f"Loaded {len(raw_data)} samples from {fdt_file}")
            
            # Reshape data - needs to account for number of channels
            n_channels = 4  # Default to 4 channels (DI, OO, ZM, CS)
            
            # Check if data can be divided evenly by number of channels
            total_samples = len(raw_data)
            if total_samples % n_channels != 0:
                print(f"Warning: Data size {total_samples} not divisible by {n_channels} channels")
                # Try to adjust to the nearest multiple
                new_size = (total_samples // n_channels) * n_channels
                raw_data = raw_data[:new_size]
                print(f"Adjusted to {len(raw_data)} samples")
            
            # Reshape to (channels, samples)
            samples_per_channel = len(raw_data) // n_channels
            data_reshaped = raw_data.reshape(samples_per_channel, n_channels).T
            print(f"Reshaped to {data_reshaped.shape} (channels, samples)")
            
            # Extract ZM channel (index 2)
            zm_channel_idx = 2
            zm_data = data_reshaped[zm_channel_idx]
            print(f"Extracted ZM channel with {len(zm_data)} samples")
            
            # Split into epochs of 435 samples
            epoch_length = 435
            n_epochs = len(zm_data) // epoch_length
            print(f"Creating {n_epochs} epochs of length {epoch_length}")
            
            for i in range(n_epochs):
                start = i * epoch_length
                end = start + epoch_length
                if end <= len(zm_data):
                    epoch = zm_data[start:end]
                    all_epochs.append(epoch)
                    epoch_names.append(f"{fdt_file.stem}_epoch{i}")
                    
                    # Get label for this specific epoch if available
                    if i in epoch_labels:
                        pre_labels.append(epoch_labels[i])
                    else:
                        pre_labels.append(None)
            
        except Exception as e:
            print(f"Error loading .fdt file: {str(e)}")
            import traceback
            traceback.print_exc()
    
    print(f"Loaded {len(all_epochs)} total epochs")
    return all_epochs, epoch_names, pre_labels

def threshold_data(signal_data, fs=2000):
    """Apply threshold-based detection to EMG signal"""
    # Preprocess signal
    b, a = signal.butter(4, [10/(fs/2), 500/(fs/2)], btype='bandpass')
    filtered = signal.filtfilt(b, a, signal_data)
    rectified = np.abs(filtered)
    
    # Generate envelope
    b_env, a_env = signal.butter(4, 10/(fs/2), btype='lowpass')
    envelope = signal.filtfilt(b_env, a_env, rectified)
    
    # Calculate threshold
    sorted_env = np.sort(envelope)
    noise_floor = np.mean(sorted_env[:int(len(sorted_env)*0.2)])
    noise_std = np.std(sorted_env[:int(len(sorted_env)*0.2)])
    
    # Try multiple threshold multipliers
    thresholds = [3.0, 2.0, 4.0, 5.0]
    results = {}
    
    for mult in thresholds:
        threshold = noise_floor + mult * noise_std
        
        # Apply threshold
        above_threshold = envelope > threshold
        
        # Find onsets and offsets
        changes = np.diff(np.concatenate([[0], above_threshold.astype(int), [0]]))
        onsets = np.where(changes == 1)[0]
        offsets = np.where(changes == -1)[0] - 1
        
        # Filter short activations (< 30ms)
        min_samples = int(0.03 * fs)
        valid_onsets = []
        valid_offsets = []
        
        for j in range(len(onsets)):
            if j < len(offsets):
                duration = offsets[j] - onsets[j]
                if duration >= min_samples:
                    valid_onsets.append(onsets[j])
                    valid_offsets.append(offsets[j])
        
        results[mult] = {
            'threshold': threshold,
            'onsets': valid_onsets,
            'offsets': valid_offsets
        }
    
    # Select best threshold
    best_mult = None
    for mult in thresholds:
        if 1 <= len(results[mult]['onsets']) <= 3:
            best_mult = mult
            break
    
    if best_mult is None:
        best_mult = 3.0  # Default
    
    return {
        'signal': signal_data,
        'envelope': envelope,
        'best_threshold': best_mult,
        'threshold_value': results[best_mult]['threshold'],
        'onsets': results[best_mult]['onsets'],
        'offsets': results[best_mult]['offsets'],
        'all_results': results
    }

def visualize_separate_bursts(result, filename, pre_label, output_dir, fs=2000):
    """
    Create two separate plots in the same image showing pre-labels and threshold labels
    
    Args:
        result: Dictionary with detection results
        filename: Filename for output
        pre_label: Pre-existing label (onset, offset) pair
        output_dir: Output directory
        fs: Sampling frequency
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Extract data
    signal = result['signal']
    onsets = result['onsets']
    offsets = result['offsets']
    
    # Create time vector
    time = np.arange(len(signal)) / fs
    
    # Create figure with two subplots
    fig, axs = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
    
    # Plot 1: Original pre-labels
    axs[0].plot(time, signal, 'b-', label='EMG Signal')
    axs[0].set_title('Original Detection (Pre-labels)')
    axs[0].set_ylabel('Amplitude')
    axs[0].grid(True)
    
    # Mark pre-existing activations if available
    has_prelabels = False
    if pre_label is not None:
        onset, offset = pre_label
        # Make sure both values are valid
        if onset is not None and offset is not None:
            # Make sure values are within valid range
            if 0 <= onset < len(time) and 0 <= offset < len(time):
                axs[0].axvspan(time[onset], time[offset], 
                              color='c', alpha=0.4, label='Detected Burst')
                has_prelabels = True
    
    if not has_prelabels:
        axs[0].text(0.5, 0.5, 'No pre-labels found', 
                   horizontalalignment='center', verticalalignment='center',
                   transform=axs[0].transAxes, fontsize=14)
    
    axs[0].legend(loc='upper right')
    
    # Plot 2: New thresholding labels
    axs[1].plot(time, signal, 'b-', label='EMG Signal')
    axs[1].set_title('New Detection (Threshold-based)')
    axs[1].set_xlabel('Time (s)')
    axs[1].set_ylabel('Amplitude')
    axs[1].grid(True)
    
    # Mark new activations
    for i in range(len(onsets)):
        if i < len(offsets):
            axs[1].axvspan(time[onsets[i]], time[offsets[i]],
                        color='y', alpha=0.4, label='Detected Burst' if i == 0 else None)
    
    if not onsets:
        axs[1].text(0.5, 0.5, 'No bursts detected', 
                   horizontalalignment='center', verticalalignment='center',
                   transform=axs[1].transAxes, fontsize=14)
    
    axs[1].legend(loc='upper right')
    
    plt.suptitle(f'Burst Detection Comparison - {filename}', fontsize=16)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f'{filename}_separate_burst_comparison.png'))
    plt.close()
    
    # Save results
    json_results = {
        'filename': filename,
        'new_onsets': [int(onset) for onset in onsets],
        'new_offsets': [int(offset) for offset in offsets],
        'new_onsets_time': [float(onset/fs) for onset in onsets],
        'new_offsets_time': [float(offset/fs) for offset in offsets]
    }
    
    # Add original labels if available
    if pre_label:
        json_results['original_onset'] = int(pre_label[0]) if pre_label[0] is not None else None
        json_results['original_offset'] = int(pre_label[1]) if pre_label[1] is not None else None
        json_results['original_onset_time'] = float(pre_label[0]/fs) if pre_label[0] is not None else None
        json_results['original_offset_time'] = float(pre_label[1]/fs) if pre_label[1] is not None else None
    
    with open(os.path.join(output_dir, f'{filename}_burst_labels.json'), 'w') as f:
        json.dump(json_results, f, indent=2)
    
    return json_results
def save_emg_data_and_labels(signal, filename, pre_label, output_dir, fs=2000):
    """
    Save EMG signal data in NPZ format and labels in JSON format
    
    Args:
        signal: EMG signal data
        filename: Filename for output
        pre_label: Pre-existing label (onset, offset) pair
        output_dir: Output directory
        fs: Sampling frequency
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Create time vector
    time = np.arange(len(signal)) / fs
    
    # Save signal data in NPZ format
    npz_path = os.path.join(output_dir, f'{filename}_emg.npz')
    np.savez(npz_path, signal=signal, time=time, fs=fs)
    
    # Create JSON with labels
    json_results = {
        'filename': filename,
        'signal_length': len(signal),
        'sampling_rate': fs
    }
    
    # Add original labels if available
    if pre_label:
        onset, offset = pre_label
        if onset is not None and offset is not None:
            json_results['onset'] = int(onset)
            json_results['offset'] = int(offset)
            json_results['onset_time'] = float(onset/fs)
            json_results['offset_time'] = float(offset/fs)
            json_results['has_valid_label'] = True
        else:
            json_results['has_valid_label'] = False
    else:
        json_results['has_valid_label'] = False
    
    # Save label to JSON file
    json_path = os.path.join(output_dir, f'{filename}_labels.json')
    with open(json_path, 'w') as f:
        json.dump(json_results, f, indent=2)
    
    return {
        'npz_path': npz_path,
        'json_path': json_path,
        'has_valid_label': json_results['has_valid_label']
    }
def main():
    """Main function"""
    data_dir = r"C:\EMG_onset_detection\LOL_project\continuous_EMG_data"
    output_dir = r"C:\EMG_onset_detection\LOL_project\continuous_prediction_data"
    os.makedirs(output_dir, exist_ok=True)
    
    # Load EMG data
    print("Loading EMG data...")
    epochs, epoch_names, pre_labels = load_emg_data(data_dir)
    
    if not epochs:
        print("No epochs loaded. Exiting.")
        return
    
    # Process each epoch
    print("Processing epochs...")
    all_results = []
    
    for i, (epoch, name, pre_label) in enumerate(zip(epochs, epoch_names, pre_labels)):
        print(f"Processing epoch {i+1}/{len(epochs)}: {name}")
        
        # Apply threshold detection
        result = threshold_data(epoch)
        
        # Visualize and save results
        json_result = save_emg_data_and_labels(result, name, pre_label, output_dir)
        all_results.append(json_result)
        
        if (i+1) % 10 == 0:
            print(f"Processed {i+1}/{len(epochs)} epochs")
    
    # Save all results
    with open(os.path.join(output_dir, 'all_burst_labels.json'), 'w') as f:
        json.dump(all_results, f, indent=2)
    
    # Generate statistics
    total_epochs = len(all_results)
    epochs_with_activity = sum(1 for result in all_results if 'new_onsets' in result and result['new_onsets'])
    total_onsets = sum(len(result['new_onsets']) for result in all_results if 'new_onsets' in result)
    
    summary = {
        "total_epochs": total_epochs,
        "epochs_with_activity": epochs_with_activity,
        "percentage_with_activity": (epochs_with_activity / total_epochs) * 100 if total_epochs > 0 else 0,
        "total_onsets_detected": total_onsets,
        "average_onsets_per_epoch": total_onsets / total_epochs if total_epochs > 0 else 0
    }
    
    with open(os.path.join(output_dir, 'burst_detection_summary.json'), 'w') as f:
        json.dump(summary, f, indent=2)
    
    print("\nSummary Statistics:")
    print(f"Total epochs processed: {total_epochs}")
    print(f"Epochs with activity: {epochs_with_activity} ({summary['percentage_with_activity']:.1f}%)")
    print(f"Total onsets detected: {total_onsets}")
    print(f"Average onsets per epoch: {summary['average_onsets_per_epoch']:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Loading EMG data...
# Processing: C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_01.fdt
# No metadata file found for C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_01.fdt
# Loaded 3993600 samples from C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_01.fdt
# Reshaped to (4, 998400) (channels, samples)
# Extracted ZM channel with 998400 samples
# Creating 2295 epochs of length 435
# Processing: C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_10.fdt
# No metadata file found for C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_10.fdt
# Loaded 4060160 samples from C:\EMG_onset_detection\LOL_project\continuous_EMG_data\EMG_continuous_10.fdt
# Reshaped to (4, 1015040) (channels, samples)
# Extracted ZM channel with 1015040 samples
# Creating 2333 epochs of length 435
# Loaded 4628 total epochs
# Processing epochs...
# Processing epoch 1/4628: EMG_continuous_01_epoch0
# Processing epoch 2/4628: EMG_continuous_01_epoch1
# Processing epoch 3/4628: EMG_continuous_01_epoch2
# Processing epoch 4/4628: EMG_continuous_01_epoch3
# Processing epoch 5/4628: EMG_continuous_01_epoch4
# Processing epoch 6/4628: EMG_continuous_01_epoch5
# Processing epoch 7/4628: EMG_continuous_01_epoch6
# Processing epoch 8/4628: EMG_continuous_01_epoch7
# Processing epoch 9/4628: EMG_continuous_01_epoch8
# Processing epoch 10/4628: EMG_continuous_01_epoch9
# Processed 10/4628 epochs
# Processing epoch 11/4628: EMG_continuous_01_epoch10
# Processing epoch 12/4628: EMG_continuous_01_epoch11
# Processing epoch 13/4628: EMG_continuous_01_epoch12
# Processing epoch 14/4628: EMG_continuous_01_epoch13
# Processing epoch 15/4628: EMG_continuous_01_epoch14
# Processing epoch 16/4628: EMG_continuous_01_epoch15
# Processing epoch 17/4628: EMG_continuous_01_epoch16
# Processing epoch 18/4628: EMG_continuous_01_epoch17
# Processing epoch 19/4628: EMG_continuous_01_epoch18
# Processing epoch 20/4628: EMG_continuous_01_epoch19
# Processed 20/4628 epochs
# Processing epoch 21/4628: EMG_continuous_01_epoch20
# Processing epoch 22/4628: EMG_continuous_01_epoch21
# Processing epoch 23/4628: EMG_continuous_01_epoch22
# Processing epoch 24/4628: EMG_continuous_01_epoch23
# Processing epoch 25/4628: EMG_continuous_01_epoch24
# Processing epoch 26/4628: EMG_continuous_01_epoch25
# Processing epoch 27/4628: EMG_continuous_01_epoch26
# Processing epoch 28/4628: EMG_continuous_01_epoch27
# Processing epoch 29/4628: EMG_continuous_01_epoch28
# Processing epoch 30/4628: EMG_continuous_01_epoch29
# Processed 30/4628 epochs
# Processing epoch 31/4628: EMG_continuous_01_epoch30
# Processing epoch 32/4628: EMG_continuous_01_epoch31
# Processing epoch 33/4628: EMG_continuous_01_epoch32
# Processing epoch 34/4628: EMG_continuous_01_epoch33
# Processing epoch 35/4628: EMG_continuous_01_epoch34
# Processing epoch 36/4628: EMG_continuous_01_epoch35
# Processing epoch 37/4628: EMG_continuous_01_epoch36
# Processing epoch 38/4628: EMG_continuous_01_epoch37
# Processing epoch 39/4628: EMG_continuous_01_epoch38
# Processing epoch 40/4628: EMG_continuous_01_epoch39
# Processed 40/4628 epochs
# Processing epoch 41/4628: EMG_continuous_01_epoch40
# Processing epoch 42/4628: EMG_continuous_01_epoch41
# Processing epoch 43/4628: EMG_continuous_01_epoch42
# Processing epoch 44/4628: EMG_continuous_01_epoch43
# Processing epoch 45/4628: EMG_continuous_01_epoch44
# Processing epoch 46/4628: EMG_continuous_01_epoch45
# Processing epoch 47/4628: EMG_continuous_01_epoch46
# Processing epoch 48/4628: EMG_continuous_01_epoch47
# Processing epoch 49/4628: EMG_continuous_01_epoch48
# Processing epoch 50/4628: EMG_continuous_01_epoch49
# Processed 50/4628 epochs
# Processing epoch 51/4628: EMG_continuous_01_epoch50
# Processing epoch 52/4628: EMG_continuous_01_epoch51
# Processing epoch 53/4628: EMG_continuous_01_epoch52
# Processing epoch 54/4628: EMG_continuous_01_epoch53
# Processing epoch 55/4628: EMG_continuous_01_epoch54
# Processing epoch 56/4628: EMG_continuous_01_epoch55
# Processing epoch 57/4628: EMG_continuous_01_epoch56
# Processing epoch 58/4628: EMG_continuous_01_epoch57
# Processing epoch 59/4628: EMG_continuous_01_epoch58
# Processing epoch 60/4628: EMG_continuous_01_epoch59
# Processed 60/4628 epochs
# Processing epoch 61/4628: EMG_continuous_01_epoch60
# Processing epoch 62/4628: EMG_continuous_01_epoch61
# Processing epoch 63/4628: EMG_continuous_01_epoch62
# Processing epoch 64/4628: EMG_continuous_01_epoch63
# Processing epoch 65/4628: EMG_continuous_01_epoch64
# Processing epoch 66/4628: EMG_continuous_01_epoch65
# Processing epoch 67/4628: EMG_continuous_01_epoch66
# Processing epoch 68/4628: EMG_continuous_01_epoch67
# Processing epoch 69/4628: EMG_continuous_01_epoch68
# Processing epoch 70/4628: EMG_continuous_01_epoch69
# Processed 70/4628 epochs
# Processing epoch 71/4628: EMG_continuous_01_epoch70
# Processing epoch 72/4628: EMG_continuous_01_epoch71
# Processing epoch 73/4628: EMG_continuous_01_epoch72
# Processing epoch 74/4628: EMG_continuous_01_epoch73
# Processing epoch 75/4628: EMG_continuous_01_epoch74
# Processing epoch 76/4628: EMG_continuous_01_epoch75
# Processing epoch 77/4628: EMG_continuous_01_epoch76
# Processing epoch 78/4628: EMG_continuous_01_epoch77
# Processing epoch 79/4628: EMG_continuous_01_epoch78
# Processing epoch 80/4628: EMG_continuous_01_epoch79
# Processed 80/4628 epochs
# Processing epoch 81/4628: EMG_continuous_01_epoch80
# Processing epoch 82/4628: EMG_continuous_01_epoch81
# Processing epoch 83/4628: EMG_continuous_01_epoch82
# Processing epoch 84/4628: EMG_continuous_01_epoch83
# Processing epoch 85/4628: EMG_continuous_01_epoch84
# Processing epoch 86/4628: EMG_continuous_01_epoch85
# Processing epoch 87/4628: EMG_continuous_01_epoch86
# Processing epoch 88/4628: EMG_continuous_01_epoch87
# Processing epoch 89/4628: EMG_continuous_01_epoch88
# Processing epoch 90/4628: EMG_continuous_01_epoch89
# Processed 90/4628 epochs
# Processing epoch 91/4628: EMG_continuous_01_epoch90
# Processing epoch 92/4628: EMG_continuous_01_epoch91
# Processing epoch 93/4628: EMG_continuous_01_epoch92
# Processing epoch 94/4628: EMG_continuous_01_epoch93
# Processing epoch 95/4628: EMG_continuous_01_epoch94
# Processing epoch 96/4628: EMG_continuous_01_epoch95
# Processing epoch 97/4628: EMG_continuous_01_epoch96
# Processing epoch 98/4628: EMG_continuous_01_epoch97
# Processing epoch 99/4628: EMG_continuous_01_epoch98
# Processing epoch 100/4628: EMG_continuous_01_epoch99
# Processed 100/4628 epochs
# Processing epoch 101/4628: EMG_continuous_01_epoch100
# Processing epoch 102/4628: EMG_continuous_01_epoch101
# Processing epoch 103/4628: EMG_continuous_01_epoch102
# Processing epoch 104/4628: EMG_continuous_01_epoch103
# Processing epoch 105/4628: EMG_continuous_01_epoch104
# Processing epoch 106/4628: EMG_continuous_01_epoch105
# Processing epoch 107/4628: EMG_continuous_01_epoch106
# Processing epoch 108/4628: EMG_continuous_01_epoch107
# Processing epoch 109/4628: EMG_continuous_01_epoch108
# Processing epoch 110/4628: EMG_continuous_01_epoch109
# Processed 110/4628 epochs
# Processing epoch 111/4628: EMG_continuous_01_epoch110
# Processing epoch 112/4628: EMG_continuous_01_epoch111
# Processing epoch 113/4628: EMG_continuous_01_epoch112
# Processing epoch 114/4628: EMG_continuous_01_epoch113
# Processing epoch 115/4628: EMG_continuous_01_epoch114
# Processing epoch 116/4628: EMG_continuous_01_epoch115
# Processing epoch 117/4628: EMG_continuous_01_epoch116
# Processing epoch 118/4628: EMG_continuous_01_epoch117
# Processing epoch 119/4628: EMG_continuous_01_epoch118
# Processing epoch 120/4628: EMG_continuous_01_epoch119
# Processed 120/4628 epochs
# Processing epoch 121/4628: EMG_continuous_01_epoch120
# Processing epoch 122/4628: EMG_continuous_01_epoch121
# Processing epoch 123/4628: EMG_continuous_01_epoch122
# Processing epoch 124/4628: EMG_continuous_01_epoch123
# Processing epoch 125/4628: EMG_continuous_01_epoch124
# Processing epoch 126/4628: EMG_continuous_01_epoch125
# Processing epoch 127/4628: EMG_continuous_01_epoch126
# Processing epoch 128/4628: EMG_continuous_01_epoch127
# Processing epoch 129/4628: EMG_continuous_01_epoch128
# Processing epoch 130/4628: EMG_continuous_01_epoch129
# Processed 130/4628 epochs
# Processing epoch 131/4628: EMG_continuous_01_epoch130
# Processing epoch 132/4628: EMG_continuous_01_epoch131
# Processing epoch 133/4628: EMG_continuous_01_epoch132
# Processing epoch 134/4628: EMG_continuous_01_epoch133
# Processing epoch 135/4628: EMG_continuous_01_epoch134
# Processing epoch 136/4628: EMG_continuous_01_epoch135
# Processing epoch 137/4628: EMG_continuous_01_epoch136
# Processing epoch 138/4628: EMG_continuous_01_epoch137
# Processing epoch 139/4628: EMG_continuous_01_epoch138
# Processing epoch 140/4628: EMG_continuous_01_epoch139
# Processed 140/4628 epochs
# Processing epoch 141/4628: EMG_continuous_01_epoch140
# Processing epoch 142/4628: EMG_continuous_01_epoch141
# Processing epoch 143/4628: EMG_continuous_01_epoch142
# Processing epoch 144/4628: EMG_continuous_01_epoch143
# Processing epoch 145/4628: EMG_continuous_01_epoch144
# Processing epoch 146/4628: EMG_continuous_01_epoch145
# Processing epoch 147/4628: EMG_continuous_01_epoch146
# Processing epoch 148/4628: EMG_continuous_01_epoch147
# Processing epoch 149/4628: EMG_continuous_01_epoch148
# Processing epoch 150/4628: EMG_continuous_01_epoch149
# Processed 150/4628 epochs
# Processing epoch 151/4628: EMG_continuous_01_epoch150
# Processing epoch 152/4628: EMG_continuous_01_epoch151
# Processing epoch 153/4628: EMG_continuous_01_epoch152
# Processing epoch 154/4628: EMG_continuous_01_epoch153
# Processing epoch 155/4628: EMG_continuous_01_epoch154
# Processing epoch 156/4628: EMG_continuous_01_epoch155
# Processing epoch 157/4628: EMG_continuous_01_epoch156
# Processing epoch 158/4628: EMG_continuous_01_epoch157
# Processing epoch 159/4628: EMG_continuous_01_epoch158
# Processing epoch 160/4628: EMG_continuous_01_epoch159
# Processed 160/4628 epochs
# Processing epoch 161/4628: EMG_continuous_01_epoch160
# Processing epoch 162/4628: EMG_continuous_01_epoch161
# Processing epoch 163/4628: EMG_continuous_01_epoch162
# Processing epoch 164/4628: EMG_continuous_01_epoch163
# Processing epoch 165/4628: EMG_continuous_01_epoch164
# Processing epoch 166/4628: EMG_continuous_01_epoch165
# Processing epoch 167/4628: EMG_continuous_01_epoch166
# Processing epoch 168/4628: EMG_continuous_01_epoch167
# Processing epoch 169/4628: EMG_continuous_01_epoch168
# Processing epoch 170/4628: EMG_continuous_01_epoch169
# Processed 170/4628 epochs
# Processing epoch 171/4628: EMG_continuous_01_epoch170
# Processing epoch 172/4628: EMG_continuous_01_epoch171
# Processing epoch 173/4628: EMG_continuous_01_epoch172
# Processing epoch 174/4628: EMG_continuous_01_epoch173
# Processing epoch 175/4628: EMG_continuous_01_epoch174
# Processing epoch 176/4628: EMG_continuous_01_epoch175
# Processing epoch 177/4628: EMG_continuous_01_epoch176
# Processing epoch 178/4628: EMG_continuous_01_epoch177
# Processing epoch 179/4628: EMG_continuous_01_epoch178
# Processing epoch 180/4628: EMG_continuous_01_epoch179
# Processed 180/4628 epochs
# Processing epoch 181/4628: EMG_continuous_01_epoch180
# Processing epoch 182/4628: EMG_continuous_01_epoch181
# Processing epoch 183/4628: EMG_continuous_01_epoch182
# Processing epoch 184/4628: EMG_continuous_01_epoch183
# Processing epoch 185/4628: EMG_continuous_01_epoch184
# Processing epoch 186/4628: EMG_continuous_01_epoch185
# Processing epoch 187/4628: EMG_continuous_01_epoch186
# Processing epoch 188/4628: EMG_continuous_01_epoch187
# Processing epoch 189/4628: EMG_continuous_01_epoch188
# Processing epoch 190/4628: EMG_continuous_01_epoch189
# Processed 190/4628 epochs
# Processing epoch 191/4628: EMG_continuous_01_epoch190
# Processing epoch 192/4628: EMG_continuous_01_epoch191
# Processing epoch 193/4628: EMG_continuous_01_epoch192
# Processing epoch 194/4628: EMG_continuous_01_epoch193
# Processing epoch 195/4628: EMG_continuous_01_epoch194
# Processing epoch 196/4628: EMG_continuous_01_epoch195
# Processing epoch 197/4628: EMG_continuous_01_epoch196
# Processing epoch 198/4628: EMG_continuous_01_epoch197
# Processing epoch 199/4628: EMG_continuous_01_epoch198
# Processing epoch 200/4628: EMG_continuous_01_epoch199
# Processed 200/4628 epochs
# Processing epoch 201/4628: EMG_continuous_01_epoch200
# Processing epoch 202/4628: EMG_continuous_01_epoch201
# Processing epoch 203/4628: EMG_continuous_01_epoch202
# Processing epoch 204/4628: EMG_continuous_01_epoch203
# Processing epoch 205/4628: EMG_continuous_01_epoch204
# Processing epoch 206/4628: EMG_continuous_01_epoch205
# Processing epoch 207/4628: EMG_continuous_01_epoch206
# Processing epoch 208/4628: EMG_continuous_01_epoch207
# Processing epoch 209/4628: EMG_continuous_01_epoch208
# Processing epoch 210/4628: EMG_continuous_01_epoch209
# Processed 210/4628 epochs
# Processing epoch 211/4628: EMG_continuous_01_epoch210
# Processing epoch 212/4628: EMG_continuous_01_epoch211
# Processing epoch 213/4628: EMG_continuous_01_epoch212
# Processing epoch 214/4628: EMG_continuous_01_epoch213
# Processing epoch 215/4628: EMG_continuous_01_epoch214
# Processing epoch 216/4628: EMG_continuous_01_epoch215
# Processing epoch 217/4628: EMG_continuous_01_epoch216
# Processing epoch 218/4628: EMG_continuous_01_epoch217
# Processing epoch 219/4628: EMG_continuous_01_epoch218
# Processing epoch 220/4628: EMG_continuous_01_epoch219
# Processed 220/4628 epochs
# Processing epoch 221/4628: EMG_continuous_01_epoch220
# Processing epoch 222/4628: EMG_continuous_01_epoch221
# Processing epoch 223/4628: EMG_continuous_01_epoch222
# Processing epoch 224/4628: EMG_continuous_01_epoch223
# Processing epoch 225/4628: EMG_continuous_01_epoch224
# Processing epoch 226/4628: EMG_continuous_01_epoch225
# Processing epoch 227/4628: EMG_continuous_01_epoch226
# Processing epoch 228/4628: EMG_continuous_01_epoch227
# Processing epoch 229/4628: EMG_continuous_01_epoch228
# Processing epoch 230/4628: EMG_continuous_01_epoch229
# Processed 230/4628 epochs
# Processing epoch 231/4628: EMG_continuous_01_epoch230
# Processing epoch 232/4628: EMG_continuous_01_epoch231
# Processing epoch 233/4628: EMG_continuous_01_epoch232
# Processing epoch 234/4628: EMG_continuous_01_epoch233
# Processing epoch 235/4628: EMG_continuous_01_epoch234
# Processing epoch 236/4628: EMG_continuous_01_epoch235
# Processing epoch 237/4628: EMG_continuous_01_epoch236
# Processing epoch 238/4628: EMG_continuous_01_epoch237
# Processing epoch 239/4628: EMG_continuous_01_epoch238
# Processing epoch 240/4628: EMG_continuous_01_epoch239
# Processed 240/4628 epochs
# Processing epoch 241/4628: EMG_continuous_01_epoch240
# Processing epoch 242/4628: EMG_continuous_01_epoch241
# Processing epoch 243/4628: EMG_continuous_01_epoch242
# Processing epoch 244/4628: EMG_continuous_01_epoch243
# Processing epoch 245/4628: EMG_continuous_01_epoch244
# Processing epoch 246/4628: EMG_continuous_01_epoch245
# Processing epoch 247/4628: EMG_continuous_01_epoch246
# Processing epoch 248/4628: EMG_continuous_01_epoch247
# Processing epoch 249/4628: EMG_continuous_01_epoch248
# Processing epoch 250/4628: EMG_continuous_01_epoch249
# Processed 250/4628 epochs
# Processing epoch 251/4628: EMG_continuous_01_epoch250
# Processing epoch 252/4628: EMG_continuous_01_epoch251
# Processing epoch 253/4628: EMG_continuous_01_epoch252
# Processing epoch 254/4628: EMG_continuous_01_epoch253
# Processing epoch 255/4628: EMG_continuous_01_epoch254
# Processing epoch 256/4628: EMG_continuous_01_epoch255
# Processing epoch 257/4628: EMG_continuous_01_epoch256
# Processing epoch 258/4628: EMG_continuous_01_epoch257
# Processing epoch 259/4628: EMG_continuous_01_epoch258
# Processing epoch 260/4628: EMG_continuous_01_epoch259
# Processed 260/4628 epochs
# Processing epoch 261/4628: EMG_continuous_01_epoch260
# Processing epoch 262/4628: EMG_continuous_01_epoch261
# Processing epoch 263/4628: EMG_continuous_01_epoch262
# Processing epoch 264/4628: EMG_continuous_01_epoch263
# Processing epoch 265/4628: EMG_continuous_01_epoch264
# Processing epoch 266/4628: EMG_continuous_01_epoch265
# Processing epoch 267/4628: EMG_continuous_01_epoch266
# Processing epoch 268/4628: EMG_continuous_01_epoch267
# Processing epoch 269/4628: EMG_continuous_01_epoch268
# Processing epoch 270/4628: EMG_continuous_01_epoch269
# Processed 270/4628 epochs
# Processing epoch 271/4628: EMG_continuous_01_epoch270
# Processing epoch 272/4628: EMG_continuous_01_epoch271
# Processing epoch 273/4628: EMG_continuous_01_epoch272
# Processing epoch 274/4628: EMG_continuous_01_epoch273
# Processing epoch 275/4628: EMG_continuous_01_epoch274
# Processing epoch 276/4628: EMG_continuous_01_epoch275
# Processing epoch 277/4628: EMG_continuous_01_epoch276
# Processing epoch 278/4628: EMG_continuous_01_epoch277
# Processing epoch 279/4628: EMG_continuous_01_epoch278
# Processing epoch 280/4628: EMG_continuous_01_epoch279
# Processed 280/4628 epochs
# Processing epoch 281/4628: EMG_continuous_01_epoch280
# Processing epoch 282/4628: EMG_continuous_01_epoch281
# Processing epoch 283/4628: EMG_continuous_01_epoch282
# Processing epoch 284/4628: EMG_continuous_01_epoch283
# Processing epoch 285/4628: EMG_continuous_01_epoch284
# Processing epoch 286/4628: EMG_continuous_01_epoch285
# Processing epoch 287/4628: EMG_continuous_01_epoch286
# Processing epoch 288/4628: EMG_continuous_01_epoch287
# Processing epoch 289/4628: EMG_continuous_01_epoch288
# Processing epoch 290/4628: EMG_continuous_01_epoch289
# Processed 290/4628 epochs
# Processing epoch 291/4628: EMG_continuous_01_epoch290
# Processing epoch 292/4628: EMG_continuous_01_epoch291
# Processing epoch 293/4628: EMG_continuous_01_epoch292
# Processing epoch 294/4628: EMG_continuous_01_epoch293
# Processing epoch 295/4628: EMG_continuous_01_epoch294
# Processing epoch 296/4628: EMG_continuous_01_epoch295
# Processing epoch 297/4628: EMG_continuous_01_epoch296
# Processing epoch 298/4628: EMG_continuous_01_epoch297
# Processing epoch 299/4628: EMG_continuous_01_epoch298
# Processing epoch 300/4628: EMG_continuous_01_epoch299
# Processed 300/4628 epochs
# Processing epoch 301/4628: EMG_continuous_01_epoch300
# Processing epoch 302/4628: EMG_continuous_01_epoch301
# Processing epoch 303/4628: EMG_continuous_01_epoch302
# Processing epoch 304/4628: EMG_continuous_01_epoch303
# Processing epoch 305/4628: EMG_continuous_01_epoch304
# Processing epoch 306/4628: EMG_continuous_01_epoch305
# Processing epoch 307/4628: EMG_continuous_01_epoch306
# Processing epoch 308/4628: EMG_continuous_01_epoch307
# Processing epoch 309/4628: EMG_continuous_01_epoch308
# Processing epoch 310/4628: EMG_continuous_01_epoch309
# Processed 310/4628 epochs
# Processing epoch 311/4628: EMG_continuous_01_epoch310
# Processing epoch 312/4628: EMG_continuous_01_epoch311
# Processing epoch 313/4628: EMG_continuous_01_epoch312
# Processing epoch 314/4628: EMG_continuous_01_epoch313
# Processing epoch 315/4628: EMG_continuous_01_epoch314
# Processing epoch 316/4628: EMG_continuous_01_epoch315
# Processing epoch 317/4628: EMG_continuous_01_epoch316
# Processing epoch 318/4628: EMG_continuous_01_epoch317
# Processing epoch 319/4628: EMG_continuous_01_epoch318
# Processing epoch 320/4628: EMG_continuous_01_epoch319
# Processed 320/4628 epochs
# Processing epoch 321/4628: EMG_continuous_01_epoch320
# Processing epoch 322/4628: EMG_continuous_01_epoch321
# Processing epoch 323/4628: EMG_continuous_01_epoch322
# Processing epoch 324/4628: EMG_continuous_01_epoch323
# Processing epoch 325/4628: EMG_continuous_01_epoch324
# Processing epoch 326/4628: EMG_continuous_01_epoch325
# Processing epoch 327/4628: EMG_continuous_01_epoch326
# Processing epoch 328/4628: EMG_continuous_01_epoch327
# Processing epoch 329/4628: EMG_continuous_01_epoch328
# Processing epoch 330/4628: EMG_continuous_01_epoch329
# Processed 330/4628 epochs
# Processing epoch 331/4628: EMG_continuous_01_epoch330
# Processing epoch 332/4628: EMG_continuous_01_epoch331
# Processing epoch 333/4628: EMG_continuous_01_epoch332
# Processing epoch 334/4628: EMG_continuous_01_epoch333
# Processing epoch 335/4628: EMG_continuous_01_epoch334
# Processing epoch 336/4628: EMG_continuous_01_epoch335
# Processing epoch 337/4628: EMG_continuous_01_epoch336
# Processing epoch 338/4628: EMG_continuous_01_epoch337
# Processing epoch 339/4628: EMG_continuous_01_epoch338
# Processing epoch 340/4628: EMG_continuous_01_epoch339
# Processed 340/4628 epochs
# Processing epoch 341/4628: EMG_continuous_01_epoch340
# Processing epoch 342/4628: EMG_continuous_01_epoch341
# Processing epoch 343/4628: EMG_continuous_01_epoch342
# Processing epoch 344/4628: EMG_continuous_01_epoch343
# Processing epoch 345/4628: EMG_continuous_01_epoch344
# Processing epoch 346/4628: EMG_continuous_01_epoch345
# Processing epoch 347/4628: EMG_continuous_01_epoch346
# Processing epoch 348/4628: EMG_continuous_01_epoch347
# Processing epoch 349/4628: EMG_continuous_01_epoch348
# Processing epoch 350/4628: EMG_continuous_01_epoch349
# Processed 350/4628 epochs
# Processing epoch 351/4628: EMG_continuous_01_epoch350
# Processing epoch 352/4628: EMG_continuous_01_epoch351
# Processing epoch 353/4628: EMG_continuous_01_epoch352
# Processing epoch 354/4628: EMG_continuous_01_epoch353
# Processing epoch 355/4628: EMG_continuous_01_epoch354
# Processing epoch 356/4628: EMG_continuous_01_epoch355
# Processing epoch 357/4628: EMG_continuous_01_epoch356
# Processing epoch 358/4628: EMG_continuous_01_epoch357
# Processing epoch 359/4628: EMG_continuous_01_epoch358
# Processing epoch 360/4628: EMG_continuous_01_epoch359
# Processed 360/4628 epochs
# Processing epoch 361/4628: EMG_continuous_01_epoch360
# Processing epoch 362/4628: EMG_continuous_01_epoch361
# Processing epoch 363/4628: EMG_continuous_01_epoch362
# Processing epoch 364/4628: EMG_continuous_01_epoch363
# Processing epoch 365/4628: EMG_continuous_01_epoch364
# Processing epoch 366/4628: EMG_continuous_01_epoch365
# Processing epoch 367/4628: EMG_continuous_01_epoch366
# Processing epoch 368/4628: EMG_continuous_01_epoch367
# Processing epoch 369/4628: EMG_continuous_01_epoch368
# Processing epoch 370/4628: EMG_continuous_01_epoch369
# Processed 370/4628 epochs
# Processing epoch 371/4628: EMG_continuous_01_epoch370
# Processing epoch 372/4628: EMG_continuous_01_epoch371
# Processing epoch 373/4628: EMG_continuous_01_epoch372
# Processing epoch 374/4628: EMG_continuous_01_epoch373
# Processing epoch 375/4628: EMG_continuous_01_epoch374
# Processing epoch 376/4628: EMG_continuous_01_epoch375
# Processing epoch 377/4628: EMG_continuous_01_epoch376
# Processing epoch 378/4628: EMG_continuous_01_epoch377
# Processing epoch 379/4628: EMG_continuous_01_epoch378
# Processing epoch 380/4628: EMG_continuous_01_epoch379
# Processed 380/4628 epochs
# Processing epoch 381/4628: EMG_continuous_01_epoch380
# Processing epoch 382/4628: EMG_continuous_01_epoch381
# Processing epoch 383/4628: EMG_continuous_01_epoch382
# Processing epoch 384/4628: EMG_continuous_01_epoch383
# Processing epoch 385/4628: EMG_continuous_01_epoch384
# Processing epoch 386/4628: EMG_continuous_01_epoch385
# Processing epoch 387/4628: EMG_continuous_01_epoch386
# Processing epoch 388/4628: EMG_continuous_01_epoch387
# Processing epoch 389/4628: EMG_continuous_01_epoch388
# Processing epoch 390/4628: EMG_continuous_01_epoch389
# Processed 390/4628 epochs
# Processing epoch 391/4628: EMG_continuous_01_epoch390
# Processing epoch 392/4628: EMG_continuous_01_epoch391
# Processing epoch 393/4628: EMG_continuous_01_epoch392
# Processing epoch 394/4628: EMG_continuous_01_epoch393
# Processing epoch 395/4628: EMG_continuous_01_epoch394
# Processing epoch 396/4628: EMG_continuous_01_epoch395
# Processing epoch 397/4628: EMG_continuous_01_epoch396
# Processing epoch 398/4628: EMG_continuous_01_epoch397
# Processing epoch 399/4628: EMG_continuous_01_epoch398
# Processing epoch 400/4628: EMG_continuous_01_epoch399
# Processed 400/4628 epochs
# Processing epoch 401/4628: EMG_continuous_01_epoch400
# Processing epoch 402/4628: EMG_continuous_01_epoch401
# Processing epoch 403/4628: EMG_continuous_01_epoch402
# Processing epoch 404/4628: EMG_continuous_01_epoch403
# Processing epoch 405/4628: EMG_continuous_01_epoch404
# Processing epoch 406/4628: EMG_continuous_01_epoch405
# Processing epoch 407/4628: EMG_continuous_01_epoch406
# Processing epoch 408/4628: EMG_continuous_01_epoch407
# Processing epoch 409/4628: EMG_continuous_01_epoch408
# Processing epoch 410/4628: EMG_continuous_01_epoch409
# Processed 410/4628 epochs
# Processing epoch 411/4628: EMG_continuous_01_epoch410
# Processing epoch 412/4628: EMG_continuous_01_epoch411
# Processing epoch 413/4628: EMG_continuous_01_epoch412
# Processing epoch 414/4628: EMG_continuous_01_epoch413
# Processing epoch 415/4628: EMG_continuous_01_epoch414
# Processing epoch 416/4628: EMG_continuous_01_epoch415
# Processing epoch 417/4628: EMG_continuous_01_epoch416
# Processing epoch 418/4628: EMG_continuous_01_epoch417
# Processing epoch 419/4628: EMG_continuous_01_epoch418
# Processing epoch 420/4628: EMG_continuous_01_epoch419
# Processed 420/4628 epochs
# Processing epoch 421/4628: EMG_continuous_01_epoch420
# Processing epoch 422/4628: EMG_continuous_01_epoch421
# Processing epoch 423/4628: EMG_continuous_01_epoch422
# Processing epoch 424/4628: EMG_continuous_01_epoch423
# Processing epoch 425/4628: EMG_continuous_01_epoch424
# Processing epoch 426/4628: EMG_continuous_01_epoch425
# Processing epoch 427/4628: EMG_continuous_01_epoch426
# Processing epoch 428/4628: EMG_continuous_01_epoch427
# Processing epoch 429/4628: EMG_continuous_01_epoch428
# Processing epoch 430/4628: EMG_continuous_01_epoch429
# Processed 430/4628 epochs
# Processing epoch 431/4628: EMG_continuous_01_epoch430
# Processing epoch 432/4628: EMG_continuous_01_epoch431
# Processing epoch 433/4628: EMG_continuous_01_epoch432
# Processing epoch 434/4628: EMG_continuous_01_epoch433
# Processing epoch 435/4628: EMG_continuous_01_epoch434
# Processing epoch 436/4628: EMG_continuous_01_epoch435
# Processing epoch 437/4628: EMG_continuous_01_epoch436
# Processing epoch 438/4628: EMG_continuous_01_epoch437
# Processing epoch 439/4628: EMG_continuous_01_epoch438
# Processing epoch 440/4628: EMG_continuous_01_epoch439
# Processed 440/4628 epochs
# Processing epoch 441/4628: EMG_continuous_01_epoch440
# Processing epoch 442/4628: EMG_continuous_01_epoch441
# Processing epoch 443/4628: EMG_continuous_01_epoch442
# Processing epoch 444/4628: EMG_continuous_01_epoch443
# Processing epoch 445/4628: EMG_continuous_01_epoch444
# Processing epoch 446/4628: EMG_continuous_01_epoch445
# Processing epoch 447/4628: EMG_continuous_01_epoch446
# Processing epoch 448/4628: EMG_continuous_01_epoch447
# Processing epoch 449/4628: EMG_continuous_01_epoch448
# Processing epoch 450/4628: EMG_continuous_01_epoch449
# Processed 450/4628 epochs
# Processing epoch 451/4628: EMG_continuous_01_epoch450
# Processing epoch 452/4628: EMG_continuous_01_epoch451
# Processing epoch 453/4628: EMG_continuous_01_epoch452
# Processing epoch 454/4628: EMG_continuous_01_epoch453
# Processing epoch 455/4628: EMG_continuous_01_epoch454
# Processing epoch 456/4628: EMG_continuous_01_epoch455
# Processing epoch 457/4628: EMG_continuous_01_epoch456
# Processing epoch 458/4628: EMG_continuous_01_epoch457
# Processing epoch 459/4628: EMG_continuous_01_epoch458
# Processing epoch 460/4628: EMG_continuous_01_epoch459
# Processed 460/4628 epochs
# Processing epoch 461/4628: EMG_continuous_01_epoch460
# Processing epoch 462/4628: EMG_continuous_01_epoch461
# Processing epoch 463/4628: EMG_continuous_01_epoch462
# Processing epoch 464/4628: EMG_continuous_01_epoch463
# Processing epoch 465/4628: EMG_continuous_01_epoch464
# Processing epoch 466/4628: EMG_continuous_01_epoch465
# Processing epoch 467/4628: EMG_continuous_01_epoch466
# Processing epoch 468/4628: EMG_continuous_01_epoch467
# Processing epoch 469/4628: EMG_continuous_01_epoch468
# Processing epoch 470/4628: EMG_continuous_01_epoch469
# Processed 470/4628 epochs
# Processing epoch 471/4628: EMG_continuous_01_epoch470
# Processing epoch 472/4628: EMG_continuous_01_epoch471
# Processing epoch 473/4628: EMG_continuous_01_epoch472
# Processing epoch 474/4628: EMG_continuous_01_epoch473
# Processing epoch 475/4628: EMG_continuous_01_epoch474
# Processing epoch 476/4628: EMG_continuous_01_epoch475
# Processing epoch 477/4628: EMG_continuous_01_epoch476
# Processing epoch 478/4628: EMG_continuous_01_epoch477
# Processing epoch 479/4628: EMG_continuous_01_epoch478
# Processing epoch 480/4628: EMG_continuous_01_epoch479
# Processed 480/4628 epochs
# Processing epoch 481/4628: EMG_continuous_01_epoch480
# Processing epoch 482/4628: EMG_continuous_01_epoch481
# Processing epoch 483/4628: EMG_continuous_01_epoch482
# Processing epoch 484/4628: EMG_continuous_01_epoch483
# Processing epoch 485/4628: EMG_continuous_01_epoch484
# Processing epoch 486/4628: EMG_continuous_01_epoch485
# Processing epoch 487/4628: EMG_continuous_01_epoch486
# Processing epoch 488/4628: EMG_continuous_01_epoch487
# Processing epoch 489/4628: EMG_continuous_01_epoch488
# Processing epoch 490/4628: EMG_continuous_01_epoch489
# Processed 490/4628 epochs
# Processing epoch 491/4628: EMG_continuous_01_epoch490
# Processing epoch 492/4628: EMG_continuous_01_epoch491
# Processing epoch 493/4628: EMG_continuous_01_epoch492
# Processing epoch 494/4628: EMG_continuous_01_epoch493
# Processing epoch 495/4628: EMG_continuous_01_epoch494
# Processing epoch 496/4628: EMG_continuous_01_epoch495
# Processing epoch 497/4628: EMG_continuous_01_epoch496
# Processing epoch 498/4628: EMG_continuous_01_epoch497
# Processing epoch 499/4628: EMG_continuous_01_epoch498
# Processing epoch 500/4628: EMG_continuous_01_epoch499
# Processed 500/4628 epochs
# Processing epoch 501/4628: EMG_continuous_01_epoch500
# Processing epoch 502/4628: EMG_continuous_01_epoch501
# Processing epoch 503/4628: EMG_continuous_01_epoch502
# Processing epoch 504/4628: EMG_continuous_01_epoch503
# Processing epoch 505/4628: EMG_continuous_01_epoch504
# Processing epoch 506/4628: EMG_continuous_01_epoch505
# Processing epoch 507/4628: EMG_continuous_01_epoch506
# Processing epoch 508/4628: EMG_continuous_01_epoch507
# Processing epoch 509/4628: EMG_continuous_01_epoch508
# Processing epoch 510/4628: EMG_continuous_01_epoch509
# Processed 510/4628 epochs
# Processing epoch 511/4628: EMG_continuous_01_epoch510
# Processing epoch 512/4628: EMG_continuous_01_epoch511
# Processing epoch 513/4628: EMG_continuous_01_epoch512
# Processing epoch 514/4628: EMG_continuous_01_epoch513
# Processing epoch 515/4628: EMG_continuous_01_epoch514
# Processing epoch 516/4628: EMG_continuous_01_epoch515
# Processing epoch 517/4628: EMG_continuous_01_epoch516
# Processing epoch 518/4628: EMG_continuous_01_epoch517
# Processing epoch 519/4628: EMG_continuous_01_epoch518
# Processing epoch 520/4628: EMG_continuous_01_epoch519
# Processed 520/4628 epochs
# Processing epoch 521/4628: EMG_continuous_01_epoch520
# Processing epoch 522/4628: EMG_continuous_01_epoch521
# Processing epoch 523/4628: EMG_continuous_01_epoch522
# Processing epoch 524/4628: EMG_continuous_01_epoch523
# Processing epoch 525/4628: EMG_continuous_01_epoch524
# Processing epoch 526/4628: EMG_continuous_01_epoch525
# Processing epoch 527/4628: EMG_continuous_01_epoch526
# Processing epoch 528/4628: EMG_continuous_01_epoch527
# Processing epoch 529/4628: EMG_continuous_01_epoch528
# Processing epoch 530/4628: EMG_continuous_01_epoch529
# Processed 530/4628 epochs
# Processing epoch 531/4628: EMG_continuous_01_epoch530
# Processing epoch 532/4628: EMG_continuous_01_epoch531
# Processing epoch 533/4628: EMG_continuous_01_epoch532
# Processing epoch 534/4628: EMG_continuous_01_epoch533
# Processing epoch 535/4628: EMG_continuous_01_epoch534
# Processing epoch 536/4628: EMG_continuous_01_epoch535
# Processing epoch 537/4628: EMG_continuous_01_epoch536
# Processing epoch 538/4628: EMG_continuous_01_epoch537
# Processing epoch 539/4628: EMG_continuous_01_epoch538
# Processing epoch 540/4628: EMG_continuous_01_epoch539
# Processed 540/4628 epochs
# Processing epoch 541/4628: EMG_continuous_01_epoch540
# Processing epoch 542/4628: EMG_continuous_01_epoch541
# Processing epoch 543/4628: EMG_continuous_01_epoch542
# Processing epoch 544/4628: EMG_continuous_01_epoch543
# Processing epoch 545/4628: EMG_continuous_01_epoch544
# Processing epoch 546/4628: EMG_continuous_01_epoch545
# Processing epoch 547/4628: EMG_continuous_01_epoch546
# Processing epoch 548/4628: EMG_continuous_01_epoch547
# Processing epoch 549/4628: EMG_continuous_01_epoch548
# Processing epoch 550/4628: EMG_continuous_01_epoch549
# Processed 550/4628 epochs
# Processing epoch 551/4628: EMG_continuous_01_epoch550
# Processing epoch 552/4628: EMG_continuous_01_epoch551
# Processing epoch 553/4628: EMG_continuous_01_epoch552
# Processing epoch 554/4628: EMG_continuous_01_epoch553
# Processing epoch 555/4628: EMG_continuous_01_epoch554
# Processing epoch 556/4628: EMG_continuous_01_epoch555
# Processing epoch 557/4628: EMG_continuous_01_epoch556
# Processing epoch 558/4628: EMG_continuous_01_epoch557
# Processing epoch 559/4628: EMG_continuous_01_epoch558
# Processing epoch 560/4628: EMG_continuous_01_epoch559
# Processed 560/4628 epochs
# Processing epoch 561/4628: EMG_continuous_01_epoch560
# Processing epoch 562/4628: EMG_continuous_01_epoch561
# Processing epoch 563/4628: EMG_continuous_01_epoch562
# Processing epoch 564/4628: EMG_continuous_01_epoch563
# Processing epoch 565/4628: EMG_continuous_01_epoch564
# Processing epoch 566/4628: EMG_continuous_01_epoch565
# Processing epoch 567/4628: EMG_continuous_01_epoch566
# Processing epoch 568/4628: EMG_continuous_01_epoch567
# Processing epoch 569/4628: EMG_continuous_01_epoch568
# Processing epoch 570/4628: EMG_continuous_01_epoch569
# Processed 570/4628 epochs
# Processing epoch 571/4628: EMG_continuous_01_epoch570
# Processing epoch 572/4628: EMG_continuous_01_epoch571
# Processing epoch 573/4628: EMG_continuous_01_epoch572
# Processing epoch 574/4628: EMG_continuous_01_epoch573
# Processing epoch 575/4628: EMG_continuous_01_epoch574
# Processing epoch 576/4628: EMG_continuous_01_epoch575
# Processing epoch 577/4628: EMG_continuous_01_epoch576
# Processing epoch 578/4628: EMG_continuous_01_epoch577
# Processing epoch 579/4628: EMG_continuous_01_epoch578
# Processing epoch 580/4628: EMG_continuous_01_epoch579
# Processed 580/4628 epochs
# Processing epoch 581/4628: EMG_continuous_01_epoch580
# Processing epoch 582/4628: EMG_continuous_01_epoch581
# Processing epoch 583/4628: EMG_continuous_01_epoch582
# Processing epoch 584/4628: EMG_continuous_01_epoch583
# Processing epoch 585/4628: EMG_continuous_01_epoch584
# Processing epoch 586/4628: EMG_continuous_01_epoch585
# Processing epoch 587/4628: EMG_continuous_01_epoch586
# Processing epoch 588/4628: EMG_continuous_01_epoch587
# Processing epoch 589/4628: EMG_continuous_01_epoch588
# Processing epoch 590/4628: EMG_continuous_01_epoch589
# Processed 590/4628 epochs
# Processing epoch 591/4628: EMG_continuous_01_epoch590
# Processing epoch 592/4628: EMG_continuous_01_epoch591
# Processing epoch 593/4628: EMG_continuous_01_epoch592
# Processing epoch 594/4628: EMG_continuous_01_epoch593
# Processing epoch 595/4628: EMG_continuous_01_epoch594
# Processing epoch 596/4628: EMG_continuous_01_epoch595
# Processing epoch 597/4628: EMG_continuous_01_epoch596
# Processing epoch 598/4628: EMG_continuous_01_epoch597
# Processing epoch 599/4628: EMG_continuous_01_epoch598
# Processing epoch 600/4628: EMG_continuous_01_epoch599
# Processed 600/4628 epochs
# Processing epoch 601/4628: EMG_continuous_01_epoch600
# Processing epoch 602/4628: EMG_continuous_01_epoch601
# Processing epoch 603/4628: EMG_continuous_01_epoch602
# Processing epoch 604/4628: EMG_continuous_01_epoch603
# Processing epoch 605/4628: EMG_continuous_01_epoch604
# Processing epoch 606/4628: EMG_continuous_01_epoch605
# Processing epoch 607/4628: EMG_continuous_01_epoch606
# Processing epoch 608/4628: EMG_continuous_01_epoch607
# Processing epoch 609/4628: EMG_continuous_01_epoch608
# Processing epoch 610/4628: EMG_continuous_01_epoch609
# Processed 610/4628 epochs
# Processing epoch 611/4628: EMG_continuous_01_epoch610
# Processing epoch 612/4628: EMG_continuous_01_epoch611
# Processing epoch 613/4628: EMG_continuous_01_epoch612
# Processing epoch 614/4628: EMG_continuous_01_epoch613
# Processing epoch 615/4628: EMG_continuous_01_epoch614
# Processing epoch 616/4628: EMG_continuous_01_epoch615
# Processing epoch 617/4628: EMG_continuous_01_epoch616
# Processing epoch 618/4628: EMG_continuous_01_epoch617
# Processing epoch 619/4628: EMG_continuous_01_epoch618
# Processing epoch 620/4628: EMG_continuous_01_epoch619
# Processed 620/4628 epochs
# Processing epoch 621/4628: EMG_continuous_01_epoch620
# Processing epoch 622/4628: EMG_continuous_01_epoch621
# Processing epoch 623/4628: EMG_continuous_01_epoch622
# Processing epoch 624/4628: EMG_continuous_01_epoch623
# Processing epoch 625/4628: EMG_continuous_01_epoch624
# Processing epoch 626/4628: EMG_continuous_01_epoch625
# Processing epoch 627/4628: EMG_continuous_01_epoch626
# Processing epoch 628/4628: EMG_continuous_01_epoch627
# Processing epoch 629/4628: EMG_continuous_01_epoch628
# Processing epoch 630/4628: EMG_continuous_01_epoch629
# Processed 630/4628 epochs
# Processing epoch 631/4628: EMG_continuous_01_epoch630
# Processing epoch 632/4628: EMG_continuous_01_epoch631
# Processing epoch 633/4628: EMG_continuous_01_epoch632
# Processing epoch 634/4628: EMG_continuous_01_epoch633
# Processing epoch 635/4628: EMG_continuous_01_epoch634
# Processing epoch 636/4628: EMG_continuous_01_epoch635
# Processing epoch 637/4628: EMG_continuous_01_epoch636
# Processing epoch 638/4628: EMG_continuous_01_epoch637
# Processing epoch 639/4628: EMG_continuous_01_epoch638
# Processing epoch 640/4628: EMG_continuous_01_epoch639
# Processed 640/4628 epochs
# Processing epoch 641/4628: EMG_continuous_01_epoch640
# Processing epoch 642/4628: EMG_continuous_01_epoch641
# Processing epoch 643/4628: EMG_continuous_01_epoch642
# Processing epoch 644/4628: EMG_continuous_01_epoch643
# Processing epoch 645/4628: EMG_continuous_01_epoch644
# Processing epoch 646/4628: EMG_continuous_01_epoch645
# Processing epoch 647/4628: EMG_continuous_01_epoch646
# Processing epoch 648/4628: EMG_continuous_01_epoch647
# Processing epoch 649/4628: EMG_continuous_01_epoch648
# Processing epoch 650/4628: EMG_continuous_01_epoch649
# Processed 650/4628 epochs
# Processing epoch 651/4628: EMG_continuous_01_epoch650
# Processing epoch 652/4628: EMG_continuous_01_epoch651
# Processing epoch 653/4628: EMG_continuous_01_epoch652
# Processing epoch 654/4628: EMG_continuous_01_epoch653
# Processing epoch 655/4628: EMG_continuous_01_epoch654
# Processing epoch 656/4628: EMG_continuous_01_epoch655
# Processing epoch 657/4628: EMG_continuous_01_epoch656
# Processing epoch 658/4628: EMG_continuous_01_epoch657
# Processing epoch 659/4628: EMG_continuous_01_epoch658
# Processing epoch 660/4628: EMG_continuous_01_epoch659
# Processed 660/4628 epochs
# Processing epoch 661/4628: EMG_continuous_01_epoch660
# Processing epoch 662/4628: EMG_continuous_01_epoch661
# Processing epoch 663/4628: EMG_continuous_01_epoch662
# Processing epoch 664/4628: EMG_continuous_01_epoch663
# Processing epoch 665/4628: EMG_continuous_01_epoch664
# Processing epoch 666/4628: EMG_continuous_01_epoch665
# Processing epoch 667/4628: EMG_continuous_01_epoch666
# Processing epoch 668/4628: EMG_continuous_01_epoch667
# Processing epoch 669/4628: EMG_continuous_01_epoch668
# Processing epoch 670/4628: EMG_continuous_01_epoch669
# Processed 670/4628 epochs
# Processing epoch 671/4628: EMG_continuous_01_epoch670
# Processing epoch 672/4628: EMG_continuous_01_epoch671
# Processing epoch 673/4628: EMG_continuous_01_epoch672
# Processing epoch 674/4628: EMG_continuous_01_epoch673
# Processing epoch 675/4628: EMG_continuous_01_epoch674
# Processing epoch 676/4628: EMG_continuous_01_epoch675
# Processing epoch 677/4628: EMG_continuous_01_epoch676
# Processing epoch 678/4628: EMG_continuous_01_epoch677
# Processing epoch 679/4628: EMG_continuous_01_epoch678
# Processing epoch 680/4628: EMG_continuous_01_epoch679
# Processed 680/4628 epochs
# Processing epoch 681/4628: EMG_continuous_01_epoch680
# Processing epoch 682/4628: EMG_continuous_01_epoch681
# Processing epoch 683/4628: EMG_continuous_01_epoch682
# Processing epoch 684/4628: EMG_continuous_01_epoch683
# Processing epoch 685/4628: EMG_continuous_01_epoch684
# Processing epoch 686/4628: EMG_continuous_01_epoch685
# Processing epoch 687/4628: EMG_continuous_01_epoch686
# Processing epoch 688/4628: EMG_continuous_01_epoch687
# Processing epoch 689/4628: EMG_continuous_01_epoch688
# Processing epoch 690/4628: EMG_continuous_01_epoch689
# Processed 690/4628 epochs
# Processing epoch 691/4628: EMG_continuous_01_epoch690
# Processing epoch 692/4628: EMG_continuous_01_epoch691
# Processing epoch 693/4628: EMG_continuous_01_epoch692
# Processing epoch 694/4628: EMG_continuous_01_epoch693
# Processing epoch 695/4628: EMG_continuous_01_epoch694
# Processing epoch 696/4628: EMG_continuous_01_epoch695
# Processing epoch 697/4628: EMG_continuous_01_epoch696
# Processing epoch 698/4628: EMG_continuous_01_epoch697
# Processing epoch 699/4628: EMG_continuous_01_epoch698
# Processing epoch 700/4628: EMG_continuous_01_epoch699
# Processed 700/4628 epochs
# Processing epoch 701/4628: EMG_continuous_01_epoch700
# Processing epoch 702/4628: EMG_continuous_01_epoch701
# Processing epoch 703/4628: EMG_continuous_01_epoch702
# Processing epoch 704/4628: EMG_continuous_01_epoch703
# Processing epoch 705/4628: EMG_continuous_01_epoch704
# Processing epoch 706/4628: EMG_continuous_01_epoch705
# Processing epoch 707/4628: EMG_continuous_01_epoch706
# Processing epoch 708/4628: EMG_continuous_01_epoch707
# Processing epoch 709/4628: EMG_continuous_01_epoch708
# Processing epoch 710/4628: EMG_continuous_01_epoch709
# Processed 710/4628 epochs
# Processing epoch 711/4628: EMG_continuous_01_epoch710
# Processing epoch 712/4628: EMG_continuous_01_epoch711
# Processing epoch 713/4628: EMG_continuous_01_epoch712
# Processing epoch 714/4628: EMG_continuous_01_epoch713
# Processing epoch 715/4628: EMG_continuous_01_epoch714
# Processing epoch 716/4628: EMG_continuous_01_epoch715
# Processing epoch 717/4628: EMG_continuous_01_epoch716
# Processing epoch 718/4628: EMG_continuous_01_epoch717
# Processing epoch 719/4628: EMG_continuous_01_epoch718
# Processing epoch 720/4628: EMG_continuous_01_epoch719
# Processed 720/4628 epochs
# Processing epoch 721/4628: EMG_continuous_01_epoch720
# Processing epoch 722/4628: EMG_continuous_01_epoch721
# Processing epoch 723/4628: EMG_continuous_01_epoch722
# Processing epoch 724/4628: EMG_continuous_01_epoch723
# Processing epoch 725/4628: EMG_continuous_01_epoch724
# Processing epoch 726/4628: EMG_continuous_01_epoch725
# Processing epoch 727/4628: EMG_continuous_01_epoch726
# Processing epoch 728/4628: EMG_continuous_01_epoch727
# Processing epoch 729/4628: EMG_continuous_01_epoch728
# Processing epoch 730/4628: EMG_continuous_01_epoch729
# Processed 730/4628 epochs
# Processing epoch 731/4628: EMG_continuous_01_epoch730
# Processing epoch 732/4628: EMG_continuous_01_epoch731
# Processing epoch 733/4628: EMG_continuous_01_epoch732
# Processing epoch 734/4628: EMG_continuous_01_epoch733
# Processing epoch 735/4628: EMG_continuous_01_epoch734
# Processing epoch 736/4628: EMG_continuous_01_epoch735
# Processing epoch 737/4628: EMG_continuous_01_epoch736
# Processing epoch 738/4628: EMG_continuous_01_epoch737
# Processing epoch 739/4628: EMG_continuous_01_epoch738
# Processing epoch 740/4628: EMG_continuous_01_epoch739
# Processed 740/4628 epochs
# Processing epoch 741/4628: EMG_continuous_01_epoch740
# Processing epoch 742/4628: EMG_continuous_01_epoch741
# Processing epoch 743/4628: EMG_continuous_01_epoch742
# Processing epoch 744/4628: EMG_continuous_01_epoch743
# Processing epoch 745/4628: EMG_continuous_01_epoch744
# Processing epoch 746/4628: EMG_continuous_01_epoch745
# Processing epoch 747/4628: EMG_continuous_01_epoch746
# Processing epoch 748/4628: EMG_continuous_01_epoch747
# Processing epoch 749/4628: EMG_continuous_01_epoch748
# Processing epoch 750/4628: EMG_continuous_01_epoch749
# Processed 750/4628 epochs
# Processing epoch 751/4628: EMG_continuous_01_epoch750
# Processing epoch 752/4628: EMG_continuous_01_epoch751
# Processing epoch 753/4628: EMG_continuous_01_epoch752
# Processing epoch 754/4628: EMG_continuous_01_epoch753
# Processing epoch 755/4628: EMG_continuous_01_epoch754
# Processing epoch 756/4628: EMG_continuous_01_epoch755
# Processing epoch 757/4628: EMG_continuous_01_epoch756
# Processing epoch 758/4628: EMG_continuous_01_epoch757
# Processing epoch 759/4628: EMG_continuous_01_epoch758
# Processing epoch 760/4628: EMG_continuous_01_epoch759
# Processed 760/4628 epochs
# Processing epoch 761/4628: EMG_continuous_01_epoch760
# Processing epoch 762/4628: EMG_continuous_01_epoch761
# Processing epoch 763/4628: EMG_continuous_01_epoch762
# Processing epoch 764/4628: EMG_continuous_01_epoch763
# Processing epoch 765/4628: EMG_continuous_01_epoch764
# Processing epoch 766/4628: EMG_continuous_01_epoch765
# Processing epoch 767/4628: EMG_continuous_01_epoch766
# Processing epoch 768/4628: EMG_continuous_01_epoch767
# Processing epoch 769/4628: EMG_continuous_01_epoch768
# Processing epoch 770/4628: EMG_continuous_01_epoch769
# Processed 770/4628 epochs
# Processing epoch 771/4628: EMG_continuous_01_epoch770
# Processing epoch 772/4628: EMG_continuous_01_epoch771
# Processing epoch 773/4628: EMG_continuous_01_epoch772
# Processing epoch 774/4628: EMG_continuous_01_epoch773
# Processing epoch 775/4628: EMG_continuous_01_epoch774
# Processing epoch 776/4628: EMG_continuous_01_epoch775
# Processing epoch 777/4628: EMG_continuous_01_epoch776
# Processing epoch 778/4628: EMG_continuous_01_epoch777
# Processing epoch 779/4628: EMG_continuous_01_epoch778
# Processing epoch 780/4628: EMG_continuous_01_epoch779
# Processed 780/4628 epochs
# Processing epoch 781/4628: EMG_continuous_01_epoch780
# Processing epoch 782/4628: EMG_continuous_01_epoch781
# Processing epoch 783/4628: EMG_continuous_01_epoch782
# Processing epoch 784/4628: EMG_continuous_01_epoch783
# Processing epoch 785/4628: EMG_continuous_01_epoch784
# Processing epoch 786/4628: EMG_continuous_01_epoch785
# Processing epoch 787/4628: EMG_continuous_01_epoch786
# Processing epoch 788/4628: EMG_continuous_01_epoch787
# Processing epoch 789/4628: EMG_continuous_01_epoch788
# Processing epoch 790/4628: EMG_continuous_01_epoch789
# Processed 790/4628 epochs
# Processing epoch 791/4628: EMG_continuous_01_epoch790
# Processing epoch 792/4628: EMG_continuous_01_epoch791
# Processing epoch 793/4628: EMG_continuous_01_epoch792
# Processing epoch 794/4628: EMG_continuous_01_epoch793
# Processing epoch 795/4628: EMG_continuous_01_epoch794
# Processing epoch 796/4628: EMG_continuous_01_epoch795
# Processing epoch 797/4628: EMG_continuous_01_epoch796
# Processing epoch 798/4628: EMG_continuous_01_epoch797
# Processing epoch 799/4628: EMG_continuous_01_epoch798
# Processing epoch 800/4628: EMG_continuous_01_epoch799
# Processed 800/4628 epochs
# Processing epoch 801/4628: EMG_continuous_01_epoch800
# Processing epoch 802/4628: EMG_continuous_01_epoch801
# Processing epoch 803/4628: EMG_continuous_01_epoch802
# Processing epoch 804/4628: EMG_continuous_01_epoch803
# Processing epoch 805/4628: EMG_continuous_01_epoch804
# Processing epoch 806/4628: EMG_continuous_01_epoch805
# Processing epoch 807/4628: EMG_continuous_01_epoch806
# Processing epoch 808/4628: EMG_continuous_01_epoch807
# Processing epoch 809/4628: EMG_continuous_01_epoch808
# Processing epoch 810/4628: EMG_continuous_01_epoch809
# Processed 810/4628 epochs
# Processing epoch 811/4628: EMG_continuous_01_epoch810
# Processing epoch 812/4628: EMG_continuous_01_epoch811
# Processing epoch 813/4628: EMG_continuous_01_epoch812
# Processing epoch 814/4628: EMG_continuous_01_epoch813
# Processing epoch 815/4628: EMG_continuous_01_epoch814
# Processing epoch 816/4628: EMG_continuous_01_epoch815
# Processing epoch 817/4628: EMG_continuous_01_epoch816
# Processing epoch 818/4628: EMG_continuous_01_epoch817
# Processing epoch 819/4628: EMG_continuous_01_epoch818
# Processing epoch 820/4628: EMG_continuous_01_epoch819
# Processed 820/4628 epochs
# Processing epoch 821/4628: EMG_continuous_01_epoch820
# Processing epoch 822/4628: EMG_continuous_01_epoch821
# Processing epoch 823/4628: EMG_continuous_01_epoch822
# Processing epoch 824/4628: EMG_continuous_01_epoch823
# Processing epoch 825/4628: EMG_continuous_01_epoch824
# Processing epoch 826/4628: EMG_continuous_01_epoch825
# Processing epoch 827/4628: EMG_continuous_01_epoch826
# Processing epoch 828/4628: EMG_continuous_01_epoch827
# Processing epoch 829/4628: EMG_continuous_01_epoch828
# Processing epoch 830/4628: EMG_continuous_01_epoch829
# Processed 830/4628 epochs
# Processing epoch 831/4628: EMG_continuous_01_epoch830
# Processing epoch 832/4628: EMG_continuous_01_epoch831
# Processing epoch 833/4628: EMG_continuous_01_epoch832
# Processing epoch 834/4628: EMG_continuous_01_epoch833
# Processing epoch 835/4628: EMG_continuous_01_epoch834
# Processing epoch 836/4628: EMG_continuous_01_epoch835
# ...
# Processing epoch 4359/4628: EMG_continuous_10_epoch2063
# Processing epoch 4360/4628: EMG_continuous_10_epoch2064
# Processed 4360/4628 epochs
# Processing epoch 4361/4628: EMG_continuous_10_epoch2065
# Processing epoch 4362/4628: EMG_continuous_10_epoch2066
# Processing epoch 4363/4628: EMG_continuous_10_epoch2067
# Processing epoch 4364/4628: EMG_continuous_10_epoch2068
# Processing epoch 4365/4628: EMG_continuous_10_epoch2069
# Processing epoch 4366/4628: EMG_continuous_10_epoch2070
# Processing epoch 4367/4628: EMG_continuous_10_epoch2071
# Processing epoch 4368/4628: EMG_continuous_10_epoch2072
# Processing epoch 4369/4628: EMG_continuous_10_epoch2073
# Processing epoch 4370/4628: EMG_continuous_10_epoch2074
# Processed 4370/4628 epochs
# Processing epoch 4371/4628: EMG_continuous_10_epoch2075
# Processing epoch 4372/4628: EMG_continuous_10_epoch2076
# Processing epoch 4373/4628: EMG_continuous_10_epoch2077
# Processing epoch 4374/4628: EMG_continuous_10_epoch2078
# Processing epoch 4375/4628: EMG_continuous_10_epoch2079
# Processing epoch 4376/4628: EMG_continuous_10_epoch2080
# Processing epoch 4377/4628: EMG_continuous_10_epoch2081
# Processing epoch 4378/4628: EMG_continuous_10_epoch2082
# Processing epoch 4379/4628: EMG_continuous_10_epoch2083
# Processing epoch 4380/4628: EMG_continuous_10_epoch2084
# Processed 4380/4628 epochs
# Processing epoch 4381/4628: EMG_continuous_10_epoch2085
# Processing epoch 4382/4628: EMG_continuous_10_epoch2086
# Processing epoch 4383/4628: EMG_continuous_10_epoch2087
# Processing epoch 4384/4628: EMG_continuous_10_epoch2088
# Processing epoch 4385/4628: EMG_continuous_10_epoch2089
# Processing epoch 4386/4628: EMG_continuous_10_epoch2090
# Processing epoch 4387/4628: EMG_continuous_10_epoch2091
# Processing epoch 4388/4628: EMG_continuous_10_epoch2092
# Processing epoch 4389/4628: EMG_continuous_10_epoch2093
# Processing epoch 4390/4628: EMG_continuous_10_epoch2094
# Processed 4390/4628 epochs
# Processing epoch 4391/4628: EMG_continuous_10_epoch2095
# Processing epoch 4392/4628: EMG_continuous_10_epoch2096
# Processing epoch 4393/4628: EMG_continuous_10_epoch2097
# Processing epoch 4394/4628: EMG_continuous_10_epoch2098
# Processing epoch 4395/4628: EMG_continuous_10_epoch2099
# Processing epoch 4396/4628: EMG_continuous_10_epoch2100
# Processing epoch 4397/4628: EMG_continuous_10_epoch2101
# Processing epoch 4398/4628: EMG_continuous_10_epoch2102
# Processing epoch 4399/4628: EMG_continuous_10_epoch2103
# Processing epoch 4400/4628: EMG_continuous_10_epoch2104
# Processed 4400/4628 epochs
# Processing epoch 4401/4628: EMG_continuous_10_epoch2105
# Processing epoch 4402/4628: EMG_continuous_10_epoch2106
# Processing epoch 4403/4628: EMG_continuous_10_epoch2107
# Processing epoch 4404/4628: EMG_continuous_10_epoch2108
# Processing epoch 4405/4628: EMG_continuous_10_epoch2109
# Processing epoch 4406/4628: EMG_continuous_10_epoch2110
# Processing epoch 4407/4628: EMG_continuous_10_epoch2111
# Processing epoch 4408/4628: EMG_continuous_10_epoch2112
# Processing epoch 4409/4628: EMG_continuous_10_epoch2113
# Processing epoch 4410/4628: EMG_continuous_10_epoch2114
# Processed 4410/4628 epochs
# Processing epoch 4411/4628: EMG_continuous_10_epoch2115
# Processing epoch 4412/4628: EMG_continuous_10_epoch2116
# Processing epoch 4413/4628: EMG_continuous_10_epoch2117
# Processing epoch 4414/4628: EMG_continuous_10_epoch2118
# Processing epoch 4415/4628: EMG_continuous_10_epoch2119
# Processing epoch 4416/4628: EMG_continuous_10_epoch2120
# Processing epoch 4417/4628: EMG_continuous_10_epoch2121
# Processing epoch 4418/4628: EMG_continuous_10_epoch2122
# Processing epoch 4419/4628: EMG_continuous_10_epoch2123
# Processing epoch 4420/4628: EMG_continuous_10_epoch2124
# Processed 4420/4628 epochs
# Processing epoch 4421/4628: EMG_continuous_10_epoch2125
# Processing epoch 4422/4628: EMG_continuous_10_epoch2126
# Processing epoch 4423/4628: EMG_continuous_10_epoch2127
# Processing epoch 4424/4628: EMG_continuous_10_epoch2128
# Processing epoch 4425/4628: EMG_continuous_10_epoch2129
# Processing epoch 4426/4628: EMG_continuous_10_epoch2130
# Processing epoch 4427/4628: EMG_continuous_10_epoch2131
# Processing epoch 4428/4628: EMG_continuous_10_epoch2132
# Processing epoch 4429/4628: EMG_continuous_10_epoch2133
# Processing epoch 4430/4628: EMG_continuous_10_epoch2134
# Processed 4430/4628 epochs
# Processing epoch 4431/4628: EMG_continuous_10_epoch2135
# Processing epoch 4432/4628: EMG_continuous_10_epoch2136
# Processing epoch 4433/4628: EMG_continuous_10_epoch2137
# Processing epoch 4434/4628: EMG_continuous_10_epoch2138
# Processing epoch 4435/4628: EMG_continuous_10_epoch2139
# Processing epoch 4436/4628: EMG_continuous_10_epoch2140
# Processing epoch 4437/4628: EMG_continuous_10_epoch2141
# Processing epoch 4438/4628: EMG_continuous_10_epoch2142
# Processing epoch 4439/4628: EMG_continuous_10_epoch2143
# Processing epoch 4440/4628: EMG_continuous_10_epoch2144
# Processed 4440/4628 epochs
# Processing epoch 4441/4628: EMG_continuous_10_epoch2145
# Processing epoch 4442/4628: EMG_continuous_10_epoch2146
# Processing epoch 4443/4628: EMG_continuous_10_epoch2147
# Processing epoch 4444/4628: EMG_continuous_10_epoch2148
# Processing epoch 4445/4628: EMG_continuous_10_epoch2149
# Processing epoch 4446/4628: EMG_continuous_10_epoch2150
# Processing epoch 4447/4628: EMG_continuous_10_epoch2151
# Processing epoch 4448/4628: EMG_continuous_10_epoch2152
# Processing epoch 4449/4628: EMG_continuous_10_epoch2153
# Processing epoch 4450/4628: EMG_continuous_10_epoch2154
# Processed 4450/4628 epochs
# Processing epoch 4451/4628: EMG_continuous_10_epoch2155
# Processing epoch 4452/4628: EMG_continuous_10_epoch2156
# Processing epoch 4453/4628: EMG_continuous_10_epoch2157
# Processing epoch 4454/4628: EMG_continuous_10_epoch2158
# Processing epoch 4455/4628: EMG_continuous_10_epoch2159
# Processing epoch 4456/4628: EMG_continuous_10_epoch2160
# Processing epoch 4457/4628: EMG_continuous_10_epoch2161
# Processing epoch 4458/4628: EMG_continuous_10_epoch2162
# Processing epoch 4459/4628: EMG_continuous_10_epoch2163
# Processing epoch 4460/4628: EMG_continuous_10_epoch2164
# Processed 4460/4628 epochs
# Processing epoch 4461/4628: EMG_continuous_10_epoch2165
# Processing epoch 4462/4628: EMG_continuous_10_epoch2166
# Processing epoch 4463/4628: EMG_continuous_10_epoch2167
# Processing epoch 4464/4628: EMG_continuous_10_epoch2168
# Processing epoch 4465/4628: EMG_continuous_10_epoch2169
# Processing epoch 4466/4628: EMG_continuous_10_epoch2170
# Processing epoch 4467/4628: EMG_continuous_10_epoch2171
# Processing epoch 4468/4628: EMG_continuous_10_epoch2172
# Processing epoch 4469/4628: EMG_continuous_10_epoch2173
# Processing epoch 4470/4628: EMG_continuous_10_epoch2174
# Processed 4470/4628 epochs
# Processing epoch 4471/4628: EMG_continuous_10_epoch2175
# Processing epoch 4472/4628: EMG_continuous_10_epoch2176
# Processing epoch 4473/4628: EMG_continuous_10_epoch2177
# Processing epoch 4474/4628: EMG_continuous_10_epoch2178
# Processing epoch 4475/4628: EMG_continuous_10_epoch2179
# Processing epoch 4476/4628: EMG_continuous_10_epoch2180
# Processing epoch 4477/4628: EMG_continuous_10_epoch2181
# Processing epoch 4478/4628: EMG_continuous_10_epoch2182
# Processing epoch 4479/4628: EMG_continuous_10_epoch2183
# Processing epoch 4480/4628: EMG_continuous_10_epoch2184
# Processed 4480/4628 epochs
# Processing epoch 4481/4628: EMG_continuous_10_epoch2185
# Processing epoch 4482/4628: EMG_continuous_10_epoch2186
# Processing epoch 4483/4628: EMG_continuous_10_epoch2187
# Processing epoch 4484/4628: EMG_continuous_10_epoch2188
# Processing epoch 4485/4628: EMG_continuous_10_epoch2189
# Processing epoch 4486/4628: EMG_continuous_10_epoch2190
# Processing epoch 4487/4628: EMG_continuous_10_epoch2191
# Processing epoch 4488/4628: EMG_continuous_10_epoch2192
# Processing epoch 4489/4628: EMG_continuous_10_epoch2193
# Processing epoch 4490/4628: EMG_continuous_10_epoch2194
# Processed 4490/4628 epochs
# Processing epoch 4491/4628: EMG_continuous_10_epoch2195
# Processing epoch 4492/4628: EMG_continuous_10_epoch2196
# Processing epoch 4493/4628: EMG_continuous_10_epoch2197
# Processing epoch 4494/4628: EMG_continuous_10_epoch2198
# Processing epoch 4495/4628: EMG_continuous_10_epoch2199
# Processing epoch 4496/4628: EMG_continuous_10_epoch2200
# Processing epoch 4497/4628: EMG_continuous_10_epoch2201
# Processing epoch 4498/4628: EMG_continuous_10_epoch2202
# Processing epoch 4499/4628: EMG_continuous_10_epoch2203
# Processing epoch 4500/4628: EMG_continuous_10_epoch2204
# Processed 4500/4628 epochs
# Processing epoch 4501/4628: EMG_continuous_10_epoch2205
# Processing epoch 4502/4628: EMG_continuous_10_epoch2206
# Processing epoch 4503/4628: EMG_continuous_10_epoch2207
# Processing epoch 4504/4628: EMG_continuous_10_epoch2208
# Processing epoch 4505/4628: EMG_continuous_10_epoch2209
# Processing epoch 4506/4628: EMG_continuous_10_epoch2210
# Processing epoch 4507/4628: EMG_continuous_10_epoch2211
# Processing epoch 4508/4628: EMG_continuous_10_epoch2212
# Processing epoch 4509/4628: EMG_continuous_10_epoch2213
# Processing epoch 4510/4628: EMG_continuous_10_epoch2214
# Processed 4510/4628 epochs
# Processing epoch 4511/4628: EMG_continuous_10_epoch2215
# Processing epoch 4512/4628: EMG_continuous_10_epoch2216
# Processing epoch 4513/4628: EMG_continuous_10_epoch2217
# Processing epoch 4514/4628: EMG_continuous_10_epoch2218
# Processing epoch 4515/4628: EMG_continuous_10_epoch2219
# Processing epoch 4516/4628: EMG_continuous_10_epoch2220
# Processing epoch 4517/4628: EMG_continuous_10_epoch2221
# Processing epoch 4518/4628: EMG_continuous_10_epoch2222
# Processing epoch 4519/4628: EMG_continuous_10_epoch2223
# Processing epoch 4520/4628: EMG_continuous_10_epoch2224
# Processed 4520/4628 epochs
# Processing epoch 4521/4628: EMG_continuous_10_epoch2225
# Processing epoch 4522/4628: EMG_continuous_10_epoch2226
# Processing epoch 4523/4628: EMG_continuous_10_epoch2227
# Processing epoch 4524/4628: EMG_continuous_10_epoch2228
# Processing epoch 4525/4628: EMG_continuous_10_epoch2229
# Processing epoch 4526/4628: EMG_continuous_10_epoch2230
# Processing epoch 4527/4628: EMG_continuous_10_epoch2231
# Processing epoch 4528/4628: EMG_continuous_10_epoch2232
# Processing epoch 4529/4628: EMG_continuous_10_epoch2233
# Processing epoch 4530/4628: EMG_continuous_10_epoch2234
# Processed 4530/4628 epochs
# Processing epoch 4531/4628: EMG_continuous_10_epoch2235
# Processing epoch 4532/4628: EMG_continuous_10_epoch2236
# Processing epoch 4533/4628: EMG_continuous_10_epoch2237
# Processing epoch 4534/4628: EMG_continuous_10_epoch2238
# Processing epoch 4535/4628: EMG_continuous_10_epoch2239
# Processing epoch 4536/4628: EMG_continuous_10_epoch2240
# Processing epoch 4537/4628: EMG_continuous_10_epoch2241
# Processing epoch 4538/4628: EMG_continuous_10_epoch2242
# Processing epoch 4539/4628: EMG_continuous_10_epoch2243
# Processing epoch 4540/4628: EMG_continuous_10_epoch2244
# Processed 4540/4628 epochs
# Processing epoch 4541/4628: EMG_continuous_10_epoch2245
# Processing epoch 4542/4628: EMG_continuous_10_epoch2246
# Processing epoch 4543/4628: EMG_continuous_10_epoch2247
# Processing epoch 4544/4628: EMG_continuous_10_epoch2248
# Processing epoch 4545/4628: EMG_continuous_10_epoch2249
# Processing epoch 4546/4628: EMG_continuous_10_epoch2250
# Processing epoch 4547/4628: EMG_continuous_10_epoch2251
# Processing epoch 4548/4628: EMG_continuous_10_epoch2252
# Processing epoch 4549/4628: EMG_continuous_10_epoch2253
# Processing epoch 4550/4628: EMG_continuous_10_epoch2254
# Processed 4550/4628 epochs
# Processing epoch 4551/4628: EMG_continuous_10_epoch2255
# Processing epoch 4552/4628: EMG_continuous_10_epoch2256
# Processing epoch 4553/4628: EMG_continuous_10_epoch2257
# Processing epoch 4554/4628: EMG_continuous_10_epoch2258
# Processing epoch 4555/4628: EMG_continuous_10_epoch2259
# Processing epoch 4556/4628: EMG_continuous_10_epoch2260
# Processing epoch 4557/4628: EMG_continuous_10_epoch2261
# Processing epoch 4558/4628: EMG_continuous_10_epoch2262
# Processing epoch 4559/4628: EMG_continuous_10_epoch2263
# Processing epoch 4560/4628: EMG_continuous_10_epoch2264
# Processed 4560/4628 epochs
# Processing epoch 4561/4628: EMG_continuous_10_epoch2265
# Processing epoch 4562/4628: EMG_continuous_10_epoch2266
# Processing epoch 4563/4628: EMG_continuous_10_epoch2267
# Processing epoch 4564/4628: EMG_continuous_10_epoch2268
# Processing epoch 4565/4628: EMG_continuous_10_epoch2269
# Processing epoch 4566/4628: EMG_continuous_10_epoch2270
# Processing epoch 4567/4628: EMG_continuous_10_epoch2271
# Processing epoch 4568/4628: EMG_continuous_10_epoch2272
# Processing epoch 4569/4628: EMG_continuous_10_epoch2273
# Processing epoch 4570/4628: EMG_continuous_10_epoch2274
# Processed 4570/4628 epochs
# Processing epoch 4571/4628: EMG_continuous_10_epoch2275
# Processing epoch 4572/4628: EMG_continuous_10_epoch2276
# Processing epoch 4573/4628: EMG_continuous_10_epoch2277
# Processing epoch 4574/4628: EMG_continuous_10_epoch2278
# Processing epoch 4575/4628: EMG_continuous_10_epoch2279
# Processing epoch 4576/4628: EMG_continuous_10_epoch2280
# Processing epoch 4577/4628: EMG_continuous_10_epoch2281
# Processing epoch 4578/4628: EMG_continuous_10_epoch2282
# Processing epoch 4579/4628: EMG_continuous_10_epoch2283
# Processing epoch 4580/4628: EMG_continuous_10_epoch2284
# Processed 4580/4628 epochs
# Processing epoch 4581/4628: EMG_continuous_10_epoch2285
# Processing epoch 4582/4628: EMG_continuous_10_epoch2286
# Processing epoch 4583/4628: EMG_continuous_10_epoch2287
# Processing epoch 4584/4628: EMG_continuous_10_epoch2288
# Processing epoch 4585/4628: EMG_continuous_10_epoch2289
# Processing epoch 4586/4628: EMG_continuous_10_epoch2290
# Processing epoch 4587/4628: EMG_continuous_10_epoch2291
# Processing epoch 4588/4628: EMG_continuous_10_epoch2292
# Processing epoch 4589/4628: EMG_continuous_10_epoch2293
# Processing epoch 4590/4628: EMG_continuous_10_epoch2294
# Processed 4590/4628 epochs
# Processing epoch 4591/4628: EMG_continuous_10_epoch2295
# Processing epoch 4592/4628: EMG_continuous_10_epoch2296
# Processing epoch 4593/4628: EMG_continuous_10_epoch2297
# Processing epoch 4594/4628: EMG_continuous_10_epoch2298
# Processing epoch 4595/4628: EMG_continuous_10_epoch2299
# Processing epoch 4596/4628: EMG_continuous_10_epoch2300
# Processing epoch 4597/4628: EMG_continuous_10_epoch2301
# Processing epoch 4598/4628: EMG_continuous_10_epoch2302
# Processing epoch 4599/4628: EMG_continuous_10_epoch2303
# Processing epoch 4600/4628: EMG_continuous_10_epoch2304
# Processed 4600/4628 epochs
# Processing epoch 4601/4628: EMG_continuous_10_epoch2305
# Processing epoch 4602/4628: EMG_continuous_10_epoch2306
# Processing epoch 4603/4628: EMG_continuous_10_epoch2307
# Processing epoch 4604/4628: EMG_continuous_10_epoch2308
# Processing epoch 4605/4628: EMG_continuous_10_epoch2309
# Processing epoch 4606/4628: EMG_continuous_10_epoch2310
# Processing epoch 4607/4628: EMG_continuous_10_epoch2311
# Processing epoch 4608/4628: EMG_continuous_10_epoch2312
# Processing epoch 4609/4628: EMG_continuous_10_epoch2313
# Processing epoch 4610/4628: EMG_continuous_10_epoch2314
# Processed 4610/4628 epochs
# Processing epoch 4611/4628: EMG_continuous_10_epoch2315
# Processing epoch 4612/4628: EMG_continuous_10_epoch2316
# Processing epoch 4613/4628: EMG_continuous_10_epoch2317
# Processing epoch 4614/4628: EMG_continuous_10_epoch2318
# Processing epoch 4615/4628: EMG_continuous_10_epoch2319
# Processing epoch 4616/4628: EMG_continuous_10_epoch2320
# Processing epoch 4617/4628: EMG_continuous_10_epoch2321
# Processing epoch 4618/4628: EMG_continuous_10_epoch2322
# Processing epoch 4619/4628: EMG_continuous_10_epoch2323
# Processing epoch 4620/4628: EMG_continuous_10_epoch2324
# Processed 4620/4628 epochs
# Processing epoch 4621/4628: EMG_continuous_10_epoch2325
# Processing epoch 4622/4628: EMG_continuous_10_epoch2326
# Processing epoch 4623/4628: EMG_continuous_10_epoch2327
# Processing epoch 4624/4628: EMG_continuous_10_epoch2328
# Processing epoch 4625/4628: EMG_continuous_10_epoch2329
# Processing epoch 4626/4628: EMG_continuous_10_epoch2330
# Processing epoch 4627/4628: EMG_continuous_10_epoch2331
# Processing epoch 4628/4628: EMG_continuous_10_epoch2332
#
# Summary Statistics:
# Total epochs processed: 4628
# Epochs with activity: 0 (0.0%)
# Total onsets detected: 0
# Average onsets per epoch: 0.00
